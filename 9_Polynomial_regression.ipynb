# %%
import numpy as np 
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dense
from tensorflow.keras.optimizers import Adam

# %%
np.random.seed(0)
points = 500

X = np.linspace(-3, 3, points)
y = np.sin(X) + np.random.uniform(-0.5, 0.5, points)

# %%
plt.scatter(X, y, s=20)
plt.show()

# %%
model = Sequential()
model.add(Dense(50, activation='sigmoid', input_dim=1))
model.add(Dense(30, activation='sigmoid'))
model.add(Dense(1))

# %%
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 50)                100
#
#  dense_1 (Dense)             (None, 30)                1530
#
#  dense_2 (Dense)             (None, 1)                 31
#
# =================================================================
# Total params: 1,661
# Trainable params: 1,661
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
adam = Adam(learning_rate=0.01)
model.compile(loss='mse', optimizer=adam)
h=model.fit(X, y, epochs=50)
# Out:
# Epoch 1/50
# 16/16 [==============================] - 0s 2ms/step - loss: 0.5780
# Epoch 2/50
# 16/16 [==============================] - 0s 2ms/step - loss: 0.2749
# Epoch 3/50
# 16/16 [==============================] - 0s 2ms/step - loss: 0.2328
# Epoch 4/50
# 16/16 [==============================] - 0s 2ms/step - loss: 0.2290
# Epoch 5/50
# 16/16 [==============================] - 0s 2ms/step - loss: 0.2226
# Epoch 6/50
# 16/16 [==============================] - 0s 6ms/step - loss: 0.2303
# Epoch 7/50
# 16/16 [==============================] - 0s 3ms/step - loss: 0.2251
# Epoch 8/50
# 16/16 [==============================] - 0s 2ms/step - loss: 0.2069
# Epoch 9/50
# 16/16 [==============================] - 0s 2ms/step - loss: 0.2016
# Epoch 10/50
# 16/16 [==============================] - 0s 2ms/step - loss: 0.1858
# Epoch 11/50
# 16/16 [==============================] - 0s 2ms/step - loss: 0.1791
# Epoch 12/50
# 16/16 [==============================] - 0s 2ms/step - loss: 0.1652
# Epoch 13/50
# 16/16 [==============================] - 0s 2ms/step - loss: 0.1578
# Epoch 14/50
# 16/16 [==============================] - 0s 2ms/step - loss: 0.1460
# Epoch 15/50
# 16/16 [==============================] - 0s 2ms/step - loss: 0.1365
# Epoch 16/50
# 16/16 [==============================] - 0s 2ms/step - loss: 0.1297
# Epoch 17/50
# 16/16 [==============================] - 0s 2ms/step - loss: 0.1277
# Epoch 18/50
# 16/16 [==============================] - 0s 2ms/step - loss: 0.1274
# Epoch 19/50
# 16/16 [==============================] - 0s 2ms/step - loss: 0.1197
# Epoch 20/50
# 16/16 [==============================] - 0s 2ms/step - loss: 0.1208
# Epoch 21/50
# 16/16 [==============================] - 0s 2ms/step - loss: 0.1152
# Epoch 22/50
# 16/16 [==============================] - 0s 2ms/step - loss: 0.1137
# Epoch 23/50
# 16/16 [==============================] - ETA: 0s - loss: 0.106 - 0s 3ms/step - loss: 0.1128
# Epoch 24/50
# 16/16 [==============================] - 0s 2ms/step - loss: 0.1130
# Epoch 25/50
# 16/16 [==============================] - 0s 2ms/step - loss: 0.1074
# Epoch 26/50
# 16/16 [==============================] - ETA: 0s - loss: 0.124 - 0s 2ms/step - loss: 0.1128
# Epoch 27/50
# 16/16 [==============================] - 0s 2ms/step - loss: 0.1243
# Epoch 28/50
# 16/16 [==============================] - 0s 2ms/step - loss: 0.1110
# Epoch 29/50
# 16/16 [==============================] - 0s 2ms/step - loss: 0.1093
# Epoch 30/50
# 16/16 [==============================] - 0s 2ms/step - loss: 0.1147
# Epoch 31/50
# 16/16 [==============================] - 0s 2ms/step - loss: 0.1074
# Epoch 32/50
# 16/16 [==============================] - 0s 2ms/step - loss: 0.1058
# Epoch 33/50
# 16/16 [==============================] - 0s 2ms/step - loss: 0.1057
# Epoch 34/50
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1021
# Epoch 35/50
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1079
# Epoch 36/50
# 16/16 [==============================] - 0s 2ms/step - loss: 0.1027
# Epoch 37/50
# 16/16 [==============================] - 0s 2ms/step - loss: 0.1023
# Epoch 38/50
# 16/16 [==============================] - 0s 2ms/step - loss: 0.1068
# Epoch 39/50
# 16/16 [==============================] - 0s 2ms/step - loss: 0.1059
# Epoch 40/50
# 16/16 [==============================] - 0s 2ms/step - loss: 0.1030
# Epoch 41/50
# 16/16 [==============================] - 0s 2ms/step - loss: 0.1016
# Epoch 42/50
# 16/16 [==============================] - 0s 2ms/step - loss: 0.1037
# Epoch 43/50
# 16/16 [==============================] - 0s 2ms/step - loss: 0.1113
# Epoch 44/50
# 16/16 [==============================] - 0s 2ms/step - loss: 0.1050
# Epoch 45/50
# 16/16 [==============================] - 0s 2ms/step - loss: 0.1016
# Epoch 46/50
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1015
# Epoch 47/50
# 16/16 [==============================] - 0s 2ms/step - loss: 0.1015
# Epoch 48/50
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0988
# Epoch 49/50
# 16/16 [==============================] - 0s 2ms/step - loss: 0.1035
# Epoch 50/50
# 16/16 [==============================] - 0s 2ms/step - loss: 0.1021

# %%
plt.plot(h.history['loss'])
plt.legend(['training', 'validation'])
plt.title('Loss')
plt.xlabel('epoch')
# Out:
# Text(0.5, 0, 'epoch')

# %%
predictions = model.predict(X)
plt.scatter(X, y)
plt.plot(X, predictions, 'ro')
plt.show()
